# %% [markdown]
# <a href="https://colab.research.google.com/github/HuangJin-De/am_NH/blob/main/discussion/20240417.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! rm -rf am_NH
! git clone https://github.com/HuangJin-De/am_NH.git
! pip3 install netcdf4
# Out:
# Cloning into 'am_NH'...
# remote: Enumerating objects: 416, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 416 (delta 19), reused 33 (delta 17), pack-reused 378
# Receiving objects: 100% (416/416), 68.64 MiB | 26.99 MiB/s, done.
# Resolving deltas: 100% (204/204), done.
# Collecting netcdf4
#   Downloading netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 18.7 MB/s eta 0:00:00
# Collecting cftime (from netcdf4)
#   Downloading cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netcdf4) (2024.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from netcdf4) (1.25.2)
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.6.3 netcdf4-1.6.5

# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc

path='am_NH'

filen=path+'/test_sh/u.nc'
fu=nc.Dataset(filen,'r')
filen=path+'/test_sh/emc.nc'
femc=nc.Dataset(filen,'r')

u=fu.variables['u'][:,:,0]
lat=fu.variables['lat'][:]
emc=femc.variables['emc'][:,:,0]

filen=path+'/test_sh/u.col.anom.erainterim.nc'
fu=nc.Dataset(filen,'r')
filen=path+'/test_sh/duepy.col.anom.erainterim.nc'
femc=nc.Dataset(filen,'r')

u_lh=fu.variables['u'][:,:,0]
lat_u_lh=fu.variables['lat'][:]
emc_lh=femc.variables['duepy'][:,:,0]
lat_emc_lh=femc.variables['latitude'][:]

print("after reading data")

n=1
fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(lat,u[n,:],lat_u_lh,u_lh[n,:],lat,lat*0.,'gray')
ax.tick_params(labelsize=5)
plt.legend(["our","LH21"],fontsize=5,loc=9)
ax.set_xlim([-90,0])
ax.set_xticks(np.arange(-90,0.1,15.))
ax.set_ylim([-10,10])
ax.set_yticks(np.arange(-10.,10.1,2.))
ax.grid(lw=0.5,alpha=0.5)
ax.set_xlabel('latitude',fontsize=6)
ax.set_ylabel('',fontsize=6)
ax.set_title('vertical-averaged zonal-mean U anomaly',fontsize=5)

n=366
fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(lat,u[n,:],lat_u_lh,u_lh[n,:],lat,lat*0.,'gray')
ax.tick_params(labelsize=5)
plt.legend(["our","LH21"],fontsize=5,loc=9)
ax.set_xlim([-90,0])
ax.set_xticks(np.arange(-90,0.1,15.))
ax.set_ylim([-10,10])
ax.set_yticks(np.arange(-10.,10.1,2.))
ax.grid(lw=0.5,alpha=0.5)
ax.set_xlabel('latitude',fontsize=6)
ax.set_ylabel('',fontsize=6)
ax.set_title('vertical-averaged zonal-mean U anomaly',fontsize=5)

n=731
fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(lat,u[n,:],lat_u_lh,u_lh[n,:],lat,lat*0.,'gray')
ax.tick_params(labelsize=5)
plt.legend(["our","LH21"],fontsize=5,loc=9)
ax.set_xlim([-90,0])
ax.set_xticks(np.arange(-90,0.1,15.))
ax.set_ylim([-10,10])
ax.set_yticks(np.arange(-10.,10.1,2.))
ax.grid(lw=0.5,alpha=0.5)
ax.set_xlabel('latitude',fontsize=6)
ax.set_ylabel('',fontsize=6)
ax.set_title('vertical-averaged zonal-mean U anomaly',fontsize=5)

n=1096
fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(lat,u[n,:],lat_u_lh,u_lh[n,:],lat,lat*0.,'gray')
ax.tick_params(labelsize=5)
plt.legend(["our","LH21"],fontsize=5,loc=9)
ax.set_xlim([-90,0])
ax.set_xticks(np.arange(-90,0.1,15.))
ax.set_ylim([-10,10])
ax.set_yticks(np.arange(-10.,10.1,2.))
ax.grid(lw=0.5,alpha=0.5)
ax.set_xlabel('latitude',fontsize=6)
ax.set_ylabel('',fontsize=6)
ax.set_title('vertical-averaged zonal-mean U anomaly',fontsize=5)
# Out:
# after reading data
# Text(0.5, 1.0, 'vertical-averaged zonal-mean U anomaly')
